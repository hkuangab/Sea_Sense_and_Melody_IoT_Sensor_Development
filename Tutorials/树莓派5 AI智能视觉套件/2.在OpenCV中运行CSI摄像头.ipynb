# %% [markdown]
# <center><img src="../image/CLBLOGO.jpg" alt="创乐博" style="width: 300px;"/></center>
#
# # 2.在OpenCV 中调用CSI摄像头
#
# @－－－－湖南创乐博智能科技有限公司－－－－<br>
# @  文件名：2.在OpenCV 中调用CSI摄像头.py <br>
# @  版本：V2.0 <br>
# @  author: zhulin<br>
# @  说明：使用picamera2库操作摄像头
# 我们来学习一下摄像头的开启方式之一吧，一般来说，对于我们使用摄像头的时候，首先我们需要测试我们的摄像头是否正常工作，画面是否清晰，让我们一起来测试我们的摄像头吧！！！<br>

# %% [markdown]
# ## 1、打印出OPENCV 版本

# %%
import cv2
print(cv2.__version__)
# Out:
# 4.10.0

# %% [markdown]
# #Uncomment These next Two Line for Pi Camera

# %%
def bgr8_to_jpeg(value, quality=75):
    return bytes(cv2.imencode('.jpg', value)[1])

# %% [markdown]
# # 2.创建显示控件

# %%
import traitlets
import ipywidgets.widgets as widgets
from IPython.display import display
makerobo_image = widgets.Image(format='jpeg', width=640, height=480)
display(makerobo_image)
# Out:
# Image(value=b'', format='jpeg', height='480', width='640')

# %% [markdown]
# # 3. 主程序

# %%
import numpy as np
import time
import ipywidgets.widgets as widgets
import libcamera
from picamera2 import Picamera2

picamera = Picamera2()
config = picamera.create_preview_configuration(main={"format": 'RGB888', "size": (640, 480)},
                                               raw={"format": "SRGGB12", "size": (1920, 1080)})
config["transform"] = libcamera.Transform(hflip=0, vflip=1)
picamera.configure(config)
picamera.start()

while True:
    frame = picamera.capture_array()
    makerobo_image.value = bgr8_to_jpeg(frame)
# Out:
# Camera __init__ sequence did not complete.
# [0:05:30.270718000] [2538]  INFO Camera camera.cpp:1020 Pipeline handler in use by another process
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File /usr/lib/python3/dist-packages/picamera2/picamera2.py:353, in Picamera2.__init__(self, camera_num, verbose_console, tuning, allocator)
#     352 try:
# --> 353     self._open_camera()
#     354     _log.debug(f"{self.camera_manager}")
#
# File /usr/lib/python3/dist-packages/picamera2/picamera2.py:565, in Picamera2._open_camera(self)
#     564 # This now throws an error if it can't open the camera.
# --> 565 self.camera.acquire()
#     567 self.is_open = True
#
# RuntimeError: Failed to acquire camera: Device or resource busy
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[9], line 7
#       4 import libcamera
#       5 from picamera2 import Picamera2
# ----> 7 picamera = Picamera2()
#       8 config = picamera.create_preview_configuration(main={"format": 'RGB888', "size": (640, 480)},
#       9                                                raw={"format": "SRGGB12", "size": (1920, 1080)})
#      10 config["transform"] = libcamera.Transform(hflip=0, vflip=1)
#
# File /usr/lib/python3/dist-packages/picamera2/picamera2.py:365, in Picamera2.__init__(self, camera_num, verbose_console, tuning, allocator)
#     363 except Exception:
#     364     _log.error("Camera __init__ sequence did not complete.")
# --> 365     raise RuntimeError("Camera __init__ sequence did not complete.")
#     366 finally:
#     367     if tuning_file is not None:
#
# RuntimeError: Camera __init__ sequence did not complete.
